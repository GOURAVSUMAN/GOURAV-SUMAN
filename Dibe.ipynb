# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isna().count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
#To check correlation between the features.
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=100,
    horizontalalignment='right'
);
#drop pre.

# %%
fig,ax = plt.subplots(figsize = (12,10))
sns.heatmap(df, annot = True, annot_kws = {"size":10})

# %%
df = df.drop(['Pregnancies'], axis=1)

# %%
sns.factorplot('Outcome',data=df,kind='count')
# Out:
# C:\Users\DELL.DESKTOP-C18N4A6\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#sns.factorplot('Pregnancies',data=df,kind='count')

# %%
sns.factorplot('Age',data=df,kind='count')

# %%
plt.boxplot(df.BMI)
plt.show()
print(df.BMI.mean())
# Out:
# 31.992578124999977

# %%
plt.boxplot(df.Age)
plt.show()
print(df.Age.mean())
# Out:
# 33.240885416666664

# %%
plt.boxplot(df.BloodPressure)
plt.show()
print(df.BloodPressure.mean())
# Out:
# 69.10546875

# %%
plt.boxplot(df.Glucose)
plt.show()
print(df.Glucose.mean())
# Out:
# 120.89453125

# %%
#plt.boxplot(df.Pregnancies)
#plt.show()
#print(df.Pregnancies.mean())

# %%
X = df[list(df.columns)[0:-1]]
Y = df[list(df.columns)[-1]]
print(X.shape)
print("__________________________________________________________________________________________________________________")
print(Y.shape)
# Out:
# (768, 7)
# __________________________________________________________________________________________________________________
# (768,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
print(X_train.shape)
print("__________________________________________________________________________________________________________________")
print(X_test.shape)
# Out:
# (537, 7)
# __________________________________________________________________________________________________________________
# (231, 7)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Importing lib for Logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
#fitting the model to X_train, Y_train.
log = LogisticRegression(random_state=42, penalty='l2')
r=log.fit(X_train, Y_train)
print(log)
print("__________________________________________________________________________________________________________________")
print("coefs:", log.coef_)
print("__________________________________________________________________________________________________________________")
print("intercept:", log.intercept_)
print("__________________________________________________________________________________________________________________")
Y_pred = log.predict(X_test)
print("__________________________________________________________________________________________________________________")
print("LR accuracy:", accuracy_score(Y_test, Y_pred))
print("__________________________________________________________________________________________________________________")
print("LR F1:", f1_score(Y_pred, Y_pred,average='weighted'))
print("__________________________________________________________________________________________________________________")
print("LR CM:\n",  confusion_matrix(Y_test, Y_pred))
LR_CON = confusion_matrix(Y_test, Y_pred)
LR_ACC = accuracy_score(Y_test, Y_pred)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=42, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# __________________________________________________________________________________________________________________
# coefs: [[ 1.13018616 -0.17894759 -0.02001698 -0.1150369   0.80769591  0.13866948
#    0.50569723]]
# __________________________________________________________________________________________________________________
# intercept: [-0.86215179]
# __________________________________________________________________________________________________________________
# __________________________________________________________________________________________________________________
# LR accuracy: 0.7402597402597403
# __________________________________________________________________________________________________________________
# LR F1: 1.0
# __________________________________________________________________________________________________________________
# LR CM:
#  [[124  27]
#  [ 33  47]]
# C:\Users\DELL.DESKTOP-C18N4A6\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#Importing lib for Decision tree analysis.
from sklearn import tree
clf_tree = tree.DecisionTreeClassifier(criterion="entropy", max_depth=5, random_state=1)
clf_tree.fit(X_train, Y_train)
print(clf_tree)
print("__________________________________________________________________________________________________________________")
tree_predictions = clf_tree.predict(X_test)
print("LR accuracy:", accuracy_score(Y_test, Y_pred))
print("__________________________________________________________________________________________________________________")
print(confusion_matrix(Y_test, tree_predictions))
print("__________________________________________________________________________________________________________________")
print("f1:", f1_score(Y_test, tree_predictions, average='weighted'))
print("__________________________________________________________________________________________________________________")
DT_CON = confusion_matrix(Y_test, tree_predictions)
DT_ACC = accuracy_score(Y_test, Y_pred)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=1, splitter='best')
# __________________________________________________________________________________________________________________
# LR accuracy: 0.7402597402597403
# __________________________________________________________________________________________________________________
# [[131  20]
#  [ 33  47]]
# __________________________________________________________________________________________________________________
# f1: 0.7651520059683325
# __________________________________________________________________________________________________________________

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(solver='adam',                          #For neural network
                    alpha=1e-1,                             #multy level pelsoptrom
                    hidden_layer_sizes=(1000,), 
                    random_state=1, 
                    verbose=True)
mlp.fit(X_train, Y_train)        #to fit the train datas
print("MLP model:", mlp)
print("__________________________________________________________________________________________________________________")
Y_pred = mlp.predict(X_test)                  #to predict.
print("NN accuracy:", accuracy_score(Y_test, Y_pred))
print("__________________________________________________________________________________________________________________")
print("NN F1:", f1_score(Y_test, Y_pred))
print("__________________________________________________________________________________________________________________")
print("NN CM:\n", confusion_matrix(Y_test, Y_pred))
print("__________________________________________________________________________________________________________________")
NN_CON = confusion_matrix(Y_test, Y_pred)
NN_ACC = accuracy_score(Y_test, Y_pred)
# Out:
# Iteration 1, loss = 0.65427219
# Iteration 2, loss = 0.60001754
# Iteration 3, loss = 0.56299796
# Iteration 4, loss = 0.53296842
# Iteration 5, loss = 0.51048991
# Iteration 6, loss = 0.49385190
# Iteration 7, loss = 0.48029570
# Iteration 8, loss = 0.47034484
# Iteration 9, loss = 0.46199137
# Iteration 10, loss = 0.45552710
# Iteration 11, loss = 0.45087613
# Iteration 12, loss = 0.44693089
# Iteration 13, loss = 0.44398475
# Iteration 14, loss = 0.44083604
# Iteration 15, loss = 0.43868179
# Iteration 16, loss = 0.43662481
# Iteration 17, loss = 0.43435821
# Iteration 18, loss = 0.43267113
# Iteration 19, loss = 0.43066779
# Iteration 20, loss = 0.42903578
# Iteration 21, loss = 0.42733014
# Iteration 22, loss = 0.42542329
# Iteration 23, loss = 0.42398485
# Iteration 24, loss = 0.42270520
# Iteration 25, loss = 0.42101886
# Iteration 26, loss = 0.41988513
# Iteration 27, loss = 0.41845176
# Iteration 28, loss = 0.41715921
# Iteration 29, loss = 0.41584688
# Iteration 30, loss = 0.41491798
# Iteration 31, loss = 0.41355674
# Iteration 32, loss = 0.41253120
# Iteration 33, loss = 0.41136918
# Iteration 34, loss = 0.41033197
# Iteration 35, loss = 0.40913214
# Iteration 36, loss = 0.40817337
# Iteration 37, loss = 0.40717861
# Iteration 38, loss = 0.40627059
# Iteration 39, loss = 0.40494184
# Iteration 40, loss = 0.40415676
# Iteration 41, loss = 0.40357594
# Iteration 42, loss = 0.40276026
# Iteration 43, loss = 0.40148550
# Iteration 44, loss = 0.40115717
# Iteration 45, loss = 0.39994441
# Iteration 46, loss = 0.39932695
# Iteration 47, loss = 0.39834353
# Iteration 48, loss = 0.39751217
# Iteration 49, loss = 0.39679513
# Iteration 50, loss = 0.39589235
# Iteration 51, loss = 0.39525609
# Iteration 52, loss = 0.39465044
# Iteration 53, loss = 0.39406350
# Iteration 54, loss = 0.39314056
# Iteration 55, loss = 0.39242318
# Iteration 56, loss = 0.39172616
# Iteration 57, loss = 0.39091183
# Iteration 58, loss = 0.39032422
# Iteration 59, loss = 0.38976037
# Iteration 60, loss = 0.38900810
# Iteration 61, loss = 0.38843818
# Iteration 62, loss = 0.38791030
# Iteration 63, loss = 0.38762023
# Iteration 64, loss = 0.38671337
# Iteration 65, loss = 0.38588188
# Iteration 66, loss = 0.38542630
# Iteration 67, loss = 0.38473579
# Iteration 68, loss = 0.38409776
# Iteration 69, loss = 0.38363952
# Iteration 70, loss = 0.38290448
# Iteration 71, loss = 0.38247950
# Iteration 72, loss = 0.38176690
# Iteration 73, loss = 0.38137062
# Iteration 74, loss = 0.38072411
# Iteration 75, loss = 0.38033660
# Iteration 76, loss = 0.38009726
# Iteration 77, loss = 0.37923960
# Iteration 78, loss = 0.37887473
# Iteration 79, loss = 0.37775848
# Iteration 80, loss = 0.37748050
# Iteration 81, loss = 0.37716570
# Iteration 82, loss = 0.37685810
# Iteration 83, loss = 0.37591548
# Iteration 84, loss = 0.37546552
# Iteration 85, loss = 0.37514390
# Iteration 86, loss = 0.37501385
# Iteration 87, loss = 0.37397782
# Iteration 88, loss = 0.37352524
# Iteration 89, loss = 0.37328346
# Iteration 90, loss = 0.37261370
# Iteration 91, loss = 0.37222604
# Iteration 92, loss = 0.37154772
# Iteration 93, loss = 0.37109470
# Iteration 94, loss = 0.37124733
# Iteration 95, loss = 0.37057851
# Iteration 96, loss = 0.36970925
# Iteration 97, loss = 0.36898291
# Iteration 98, loss = 0.36889627
# Iteration 99, loss = 0.36887117
# Iteration 100, loss = 0.36790237
# Iteration 101, loss = 0.36761879
# Iteration 102, loss = 0.36716191
# Iteration 103, loss = 0.36668499
# Iteration 104, loss = 0.36598208
# Iteration 105, loss = 0.36575335
# Iteration 106, loss = 0.36530341
# Iteration 107, loss = 0.36471738
# Iteration 108, loss = 0.36505495
# Iteration 109, loss = 0.36404345
# Iteration 110, loss = 0.36350579
# Iteration 111, loss = 0.36345406
# Iteration 112, loss = 0.36304450
# Iteration 113, loss = 0.36215997
# Iteration 114, loss = 0.36158331
# Iteration 115, loss = 0.36110914
# Iteration 116, loss = 0.36099785
# Iteration 117, loss = 0.36019640
# Iteration 118, loss = 0.35969863
# Iteration 119, loss = 0.35953670
# Iteration 120, loss = 0.35896717
# Iteration 121, loss = 0.35867993
# Iteration 122, loss = 0.35803205
# Iteration 123, loss = 0.35841857
# Iteration 124, loss = 0.35726428
# Iteration 125, loss = 0.35647896
# Iteration 126, loss = 0.35649039
# Iteration 127, loss = 0.35584142
# Iteration 128, loss = 0.35552169
# Iteration 129, loss = 0.35476910
# Iteration 130, loss = 0.35481695
# Iteration 131, loss = 0.35497321
# Iteration 132, loss = 0.35386667
# Iteration 133, loss = 0.35302602
# Iteration 134, loss = 0.35318558
# Iteration 135, loss = 0.35252323
# Iteration 136, loss = 0.35193221
# Iteration 137, loss = 0.35184849
# Iteration 138, loss = 0.35144174
# Iteration 139, loss = 0.35089200
# Iteration 140, loss = 0.35080465
# Iteration 141, loss = 0.34993209
# Iteration 142, loss = 0.34917847
# Iteration 143, loss = 0.34892176
# Iteration 144, loss = 0.34859479
# Iteration 145, loss = 0.34810986
# Iteration 146, loss = 0.34784034
# Iteration 147, loss = 0.34748718
# Iteration 148, loss = 0.34713627
# Iteration 149, loss = 0.34662121
# Iteration 150, loss = 0.34587995
# Iteration 151, loss = 0.34531079
# Iteration 152, loss = 0.34565010
# Iteration 153, loss = 0.34467843
# Iteration 154, loss = 0.34409844
# Iteration 155, loss = 0.34470877
# Iteration 156, loss = 0.34340756
# Iteration 157, loss = 0.34344872
# Iteration 158, loss = 0.34244600
# Iteration 159, loss = 0.34190626
# Iteration 160, loss = 0.34201846
# Iteration 161, loss = 0.34118169
# Iteration 162, loss = 0.34090660
# Iteration 163, loss = 0.34037993
# Iteration 164, loss = 0.34010358
# Iteration 165, loss = 0.33912350
# Iteration 166, loss = 0.33915669
# Iteration 167, loss = 0.33895698
# Iteration 168, loss = 0.33797830
# Iteration 169, loss = 0.33778359
# Iteration 170, loss = 0.33780054
# Iteration 171, loss = 0.33757691
# Iteration 172, loss = 0.33727237
# Iteration 173, loss = 0.33598860
# Iteration 174, loss = 0.33565981
# Iteration 175, loss = 0.33616721
# Iteration 176, loss = 0.33492115
# Iteration 177, loss = 0.33447972
# Iteration 178, loss = 0.33394537
# Iteration 179, loss = 0.33395854
# Iteration 180, loss = 0.33316501
# Iteration 181, loss = 0.33328840
# Iteration 182, loss = 0.33226495
# Iteration 183, loss = 0.33211650
# Iteration 184, loss = 0.33139258
# Iteration 185, loss = 0.33157712
# Iteration 186, loss = 0.33057733
# Iteration 187, loss = 0.33004519
# Iteration 188, loss = 0.33124947
# Iteration 189, loss = 0.32994959
# Iteration 190, loss = 0.32868533
# Iteration 191, loss = 0.32832871
# Iteration 192, loss = 0.32865065
# Iteration 193, loss = 0.32783458
# Iteration 194, loss = 0.32753940
# Iteration 195, loss = 0.32655597
# Iteration 196, loss = 0.32636828
# Iteration 197, loss = 0.32646318
# Iteration 198, loss = 0.32593131
# Iteration 199, loss = 0.32508435
# Iteration 200, loss = 0.32473309
# MLP model: MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(1000,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=True, warm_start=False)
# __________________________________________________________________________________________________________________
# NN accuracy: 0.7402597402597403
# __________________________________________________________________________________________________________________
# NN F1: 0.6341463414634146
# __________________________________________________________________________________________________________________
# NN CM:
#  [[119  32]
#  [ 28  52]]
# __________________________________________________________________________________________________________________
# C:\Users\DELL.DESKTOP-C18N4A6\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
logit_roc_auc = roc_auc_score(Y_test, log.predict(X_test))
fpr, tpr, thresholds = roc_curve(Y_test, log.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
#--------------------------------------------------------------------------
print("__________________________________________________________________________________________________________________")
print("confusion matrix:- ",LR_CON)
print("__________________________________________________________________________________________________________________")
print("accuracy scores:- ",LR_ACC*100,"%")
print("__________________________________________________________________________________________________________________")
# Out:
# __________________________________________________________________________________________________________________
# confusion matrix:-  [[120  31]
#  [ 30  50]]
# __________________________________________________________________________________________________________________
# accuracy scores:-  73.59307359307358 %
# __________________________________________________________________________________________________________________

# %%
DEC_roc_auc = roc_auc_score(Y_test, clf_tree.predict(X_test))
fpr, tpr, thresholds = roc_curve(Y_test, clf_tree.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree (area = %0.2f)' % DEC_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
#------------------------------------------------------------------------------------------------------------------------------
print("__________________________________________________________________________________________________________________")
print("confusion matrix:- ",DT_CON)
print("__________________________________________________________________________________________________________________")
print("accuracy scores:- ",DT_ACC*100,"%")
print("__________________________________________________________________________________________________________________")
# Out:
# __________________________________________________________________________________________________________________
# confusion matrix:-  [[133  18]
#  [ 33  47]]
# __________________________________________________________________________________________________________________
# accuracy scores:-  73.59307359307358 %
# __________________________________________________________________________________________________________________

# %%
NN_roc_auc = roc_auc_score(Y_test, mlp.predict(X_test))
fpr, tpr, thresholds = roc_curve(Y_test, mlp.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree (area = %0.2f)' % NN_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
#--------------------------------------------------------------------------------------------------------------------------
print("__________________________________________________________________________________________________________________")
print("accuracy scores:- ",NN_ACC*100,"%")
print("__________________________________________________________________________________________________________________")
print("confusion matrix:- ",NN_CON)
print("__________________________________________________________________________________________________________________")
# Out:
# __________________________________________________________________________________________________________________
# accuracy scores:-  74.02597402597402 %
# __________________________________________________________________________________________________________________
# confusion matrix:-  [[119  32]
#  [ 28  52]]
# __________________________________________________________________________________________________________________

# %%
from sklearn.ensemble import RandomForestClassifier
clf_rf = RandomForestClassifier(max_depth=15,
                                n_estimators=100, 
                                criterion='entropy', 
                                random_state=1)
clf_rf.fit(X_train, Y_train)
print(clf_rf)
rf_predictions = clf_rf.predict(X_test)
print(confusion_matrix(Y_test, rf_predictions))
print("f1:", f1_score(Y_test, rf_predictions, average="weighted"))
print("RF accuracy:", accuracy_score(Y_test, Y_pred))
RF_accuracy = accuracy_score(Y_test, Y_pred)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=15, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)
# [[120  31]
#  [ 27  53]]
# f1: 0.7502946118104081
# RF accuracy: 0.7402597402597403

# %%
from sklearn.neighbors import KNeighborsClassifier
clf_knn = KNeighborsClassifier(n_neighbors=10, p=2)
clf_knn.fit(X_train, Y_train)
print(clf_knn)
knn_predictions_test = clf_knn.predict(X_test)
print("CM:")
print(confusion_matrix(Y_test, knn_predictions_test))
print("f1:", f1_score(Y_test, knn_predictions_test, average="weighted"))
scores = []
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')
# CM:
# [[134  17]
#  [ 42  38]]
# f1: 0.7307029814675073

# %%
RF_roc_auc = roc_auc_score(Y_test, clf_rf.predict(X_test))
fpr, tpr, thresholds = roc_curve(Y_test, clf_rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree (area = %0.2f)' % RF_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
#--------------------------------------------------------------------------------------------------------------------------
print("__________________________________________________________________________________________________________________")
print("accuracy scores:- ",RF_accuracy*100,"%")
print("__________________________________________________________________________________________________________________")
print("confusion matrix:- ",NN_CON)
print("__________________________________________________________________________________________________________________")
# Out:
# __________________________________________________________________________________________________________________
# accuracy scores:-  74.02597402597402 %
# __________________________________________________________________________________________________________________
# confusion matrix:-  [[119  32]
#  [ 28  52]]
# __________________________________________________________________________________________________________________

# %%
 KNN_roc_auc = roc_auc_score(Y_test, clf_knn.predict(X_test))
fpr, tpr, thresholds = roc_curve(Y_test, clf_knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree (area = %0.2f)' % KNN_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
#--------------------------------------------------------------------------------------------------------------------------
print("__________________________________________________________________________________________________________________")
print("accuracy scores:- ",RF_accuracy*100,"%")
print("__________________________________________________________________________________________________________________")
print("confusion matrix:- ",NN_CON)
print("__________________________________________________________________________________________________________________")
# Out:
# __________________________________________________________________________________________________________________
# accuracy scores:-  71.42857142857143 %
# __________________________________________________________________________________________________________________
# confusion matrix:-  [[117  34]
#  [ 32  48]]
# __________________________________________________________________________________________________________________
